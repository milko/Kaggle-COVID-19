# %%
from kaggle_covid_19.data import coders_against_covid

# %%
kFILE_PATH = '/Users/milko/Local/Data/Disease/Kaggle-COVID-19/coders_against_covid/crowd-sourced-covid-19-testing-locations.csv'
kUSER_NAME = 'playgrounds'
kUSER_PASS = 'playgrounds'

# %%
df = coders_against_covid(file=kFILE_PATH)
df.head()
# Out:
#                             location_id  is_verified  is_hidden  \
# 0  a3b3214a-e128-4c68-ac18-a467482f1ab8         True      False
# 1  823ece97-d901-4dd6-9a4e-b5a86d61230e         True      False
# 2  f15df801-b396-45d7-b689-c0cc7fca3e0b         True      False
# 3  ff18e912-fe0f-4823-a4cb-698e3f92a345         True      False
# 4  372769c0-2497-4353-8a4f-035e9e575852         True      False
#
#   is_location_screening_patients is_location_collecting_specimens  \
# 0                           True                             True
# 1                          False                            False
# 2                           True                             True
# 3                           True                             True
# 4                           True                             True
#
#                                   location_name     location_address_street  \
# 0              Providence Alaska Medical Center       3200 Providence Drive
# ...

# %%
df = coders_against_covid(file=kFILE_PATH, user=kUSER_NAME, pswd=kUSER_PASS)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4159 entries, 0 to 4158
# Data columns (total 28 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   location_id                                           4159 non-null   object
#  1   is_verified                                           4159 non-null   bool
#  2   is_hidden                                             4159 non-null   bool
#  3   is_location_screening_patients                        4120 non-null   object
#  4   is_location_collecting_specimens                      4152 non-null   object
#  5   location_name                                         4159 non-null   object
#  6   location_address_street                               4159 non-null   object
#  7   location_address_locality                             4159 non-null   object
# ...

# %%
df = coders_against_covid(user=kUSER_NAME, pswd=kUSER_PASS)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4158 entries, 0 to 4157
# Data columns (total 26 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   location_id                                           4158 non-null   object
#  1   is_verified                                           4158 non-null   bool
#  2   is_hidden                                             4158 non-null   bool
#  3   is_location_screening_patients                        4119 non-null   object
#  4   is_location_collecting_specimens                      4151 non-null   object
#  5   location_name                                         4158 non-null   object
#  6   location_address_street                               4158 non-null   object
#  7   location_address_locality                             4158 non-null   object
# ...

# %%
df = coders_against_covid(
    find='FOR d IN `coders_against_covid` FILTER d.`is_verified` == true RETURN d',
    user=kUSER_NAME,
    pswd=kUSER_PASS
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241 entries, 0 to 1240
# Data columns (total 26 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   location_id                                           1241 non-null   object
#  1   is_verified                                           1241 non-null   bool
#  2   is_hidden                                             1241 non-null   bool
#  3   is_location_screening_patients                        1205 non-null   object
#  4   is_location_collecting_specimens                      1234 non-null   object
#  5   location_name                                         1241 non-null   object
#  6   location_address_street                               1241 non-null   object
#  7   location_address_locality                             1241 non-null   object
# ...
